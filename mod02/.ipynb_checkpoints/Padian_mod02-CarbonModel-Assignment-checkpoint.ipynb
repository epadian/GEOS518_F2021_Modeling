# %% [markdown]
# # Module 02: A Box Model Carbon Assignment
#
# ### 1. Introduction
#
# In the accompanying notebook [mod02-CarbonModel1.ipynb](./mod02-CarbonModel1.ipynb) and in class we developed a relatively simple model of global carbon balance that assumed that tracked carbon in the atmosphere and biosphere. The system of equations we developed to describe this system are shown below,
#
# $$
# \begin{align*}
# \frac{dM_1}{dt} &= F_{21} - F_{12}\\
# &= k_{21}M_2 - k_{12}M_1
# \end{align*}
# $$
#
# and,
#
# $$
# \begin{align*}
# \frac{dM_2}{dt} &= F_{12} - F_{21}\\
# &= k_{12}M_1 - k_{21}M_2
# \end{align*}
# $$
#
# where $M_1$ is the mass of carbon in the atmosphere (GtC), $M_2$ is the mass of carbon in the biosphere (GtC), $F_{12}$ is the flux of carbon from the atmosphere to the biosphere due to photosynthesis (GtC/yr), and $F_{21}$ is the flux of carbon from the biosphere to the atmosphere due to decay and respiration (GtC/yr).
#
# In that notebook we develop a numerical model to describe that system, run it for given initial conditions and with no external inputs of carbon (we call this an "unforced" scenario) and compare it to the analytical solution. We observed that as the time step increased, we departed further from the analytical solution.
#
# In this assignment you will take your model one step more realistic by ensuring that the photosynthetic flux depends on both the amount of carbon in the atmosphere and in the biosphere. Then you will examine the impact of anthropogenic emissions from 1751-2008 on the biosphere and atmosphere, and how alternative future scenarios of emissions mitigation affect your system.
#
# The code cell below contains a couple of new commands and some file names that you will need in this assignment. You will need all of these commands, _but not necessarily

# %%
import numpy as np
import matplotlib.pyplot as plt

historical_emissions_file = 'AnthropogenicEmissions.1751_2008.csv'
data = np.loadtxt(historical_emissions_file, delimiter=',', skiprows=1)
# Read this documentation to understand what this command does: 
#    https://numpy.org/doc/stable/reference/generated/numpy.loadtxt.html
year = data[:,0]
cflux = data[:,1]

cflux_t = np.interp(t, year, cflux)
# Read this documentation to understand what this command does: 
#    https://numpy.org/doc/stable/reference/generated/numpy.interp.html

np.diff(M1)
# Read this documentation to understand what this command does: 
#    https://numpy.org/doc/stable/reference/generated/numpy.diff.html

# %% [markdown]
# ## 2. Assignment Tasks
#
# For all plots, label all axes and provide units.
#
# __Problem A: Modify and rerun the model__
#
# 1. Modify the model so that the photosynthesis flux includes the mass of carbon in the land (i.e., $M_2$). Use the following parameters:
#
#   * $M_1^0$ = 1100.0
#   * $M_2^0$ = 300.0
#   * $k_{12}$ = 0.0003
#   * $k_{21}$ = 0.1
#
# 2. Repeat the "unforced" (i.e., no anthropogenic emissions) simulation above, but run the model for `t = 100` years with a daily time step (i.e., `dt = 1/365`)
# 3. Use the `print()` command to print out the value of $M_1$ and $M_2$ at the end of the simulation
#
# __Problem B: Examine impacts of human emissions__
#
# 1. Load the anthropogenic emissions data for 1751-2008 (see numpy `np.loadtxt()` command usage [here](https://numpy.org/doc/stable/reference/generated/numpy.loadtxt.html)). Note that the data is in a comma separated variable file (named `AnthropogenicEmissions.1751_2008.csv`) with one header row.
# 2. Plot the anthropogenic emissions data
# 3. Starting from the initial conditions ($M_1^0$ and $M_2^0$) corresponding to the final conditions noted in part __A(3)__ above, simulate the response of the carbon system to the anthropogenic emissions from 1751 to 2008 by adding an appropriate source term in the system of equations. Create the following plots:
#
#   * Mass of C in the atmosphere versus time
#   * Mass of C in the land versus time
#   * The change in mass of C in the atmosphere vs time
#   * The change in mass of C in the biosphere vs time
#
# 4. Use the `print()` command to print out the value of $M_1$ and $M_2$ at the end of the simulation in 2008.
#
# __Problem C: Examine the effects of mitigation__
#
# 1. Load the alternative emission scenarios contained in the file `.csv`, which represent three pathways to net zero emissions: (a) net zero emissions by the year 2030 (column 2), (c) net zero emissions by 2050 (column 3), and zero emissions growth (i.e., constant emissions) starting in 2008 (column 4).
# 2. Starting from the initial conditions ($M_1^0$ and $M_2^0$) corresponding to the final conditions noted in part __B(4)__ above, run the model three times, one for each scenario. Create the following plots:
#
#   * Mass of C in the atmosphere versus time (all three scenarios on one plot)
#   * Mass of C in the land versus time (all three scenarios on one plot)
#   * The change in mass of C in the atmosphere vs time
#   * The change in mass of C in the biosphere vs time

# %%
#### Problem A ####

import numpy as np
import matplotlib.pyplot as plt

M1i = 1100.0    # Mass of carbon in atmosphere [Gigatons of Carbon, GtC]
M2i = 300.0     # Mass of carbon in "land/ocean" [GtC]

k12 = 0.0003    # Constant to describe land/ocean to atmosphere flux [1/yr] "turnover time or resonance time" [this is larger]
k21 = 0.1       # Constant to describe atmosphere to land/ocean flux [1/yr] "turnover time or resonance time"

ti = 0.0        # Initial time step [years]
tf = 100.0      # Final time step [years]
dt = 1/365      # Time step interval

t = np.arange(ti,tf+dt,dt)                        # Arrange the time steps

Nt = t.size                                       # Establish the length of time

print('t has '+str(Nt)+' time steps')    # Display the number of time steps we are using

M1 = np.zeros((Nt,))     # Create empty array to fill in for mass of carbon in atmosphere
M2 = np.zeros((Nt,))     # Create empty array to fill in for mass of carbon in the land/ocean

# This is the numerical solution

for i in np.arange(Nt):                        # Using a for loop, go through each equal time step in Nt and complete below
    if (i==0):                                 # If i = 0, then the mass in each "bin" equals the initial conditions

        M1[i] = M1i                            # Mass of carbon in atmosphere at time step 0 in array M1 is initial condition
        M2[i] = M2i                            # Mass of carbon in land/ocean at time step 0 in array M2 is initial condition
        
    else:                                      # If i /= 0, then complete the calculations below
        dM1dt = k21*M2[i-1] - k12*M1[i-1]      # Change in carbon in atmos wrt at i-1 equation
        dM2dt = k12*M1[i-1] - k21*M2[i-1]      # Change in carbon in land/ocean wrt at i-1 equation
        
        M1[i] = M1[i-1] + dM1dt*dt             # Insert value into M1 array of previous value plus the change calculated above
        M2[i] = M2[i-1] + dM2dt*dt             # Insert value into M2 array of previous value plus the change calculated above


print("Mass of Carbon in the Atmosphere [GtC]") # Print a label for value below
print(M1[-1])                                   # Display the last value in M1 array
print("Mass of Carbon in the Land/Ocean [GtC]") # Print a label for value below  
print(M2[-1])                                   # Display the last value in the M2 array
# Out:
# t has 36501 time steps
# Mass of Carbon in the Atmosphere [GtC]
# 1395.799547307703
# Mass of Carbon in the Land/Ocean [GtC]
# 4.200452692299009

# %%
#### Problem B ####

import numpy as np
import matplotlib.pyplot as plt

historical_emissions_file = 'AnthropogenicEmissions.1751_2008.csv'      # Create a file to pull data from
data = np.loadtxt(historical_emissions_file, delimiter=',', skiprows=1) # Read out data using a comma delimiter

year = data[:,0]   # Create array for years
cflux = data[:,1]  # Create array for carbon flux values

plt.figure(figsize=(8.5,11))                   # Create a new plot
plt.rcParams.update({'font.size': 16})         # Dictate the font size in the plot
plt.plot(year,cflux)                           # Give x and y values to the plot
plt.xlabel('Time [years]')                     # Create a label for the x axis
plt.ylabel('Carbon [GtC]')                     # Create a label for the y axis
plt.title('Anthropogenic Emissions 1751-2008') # Create a title for the entire plot

### Run the model using the end values from Problem A

M1i = M1[-1]    # Mass of carbon in atmosphere [Gigatons of Carbon, GtC]
M2i = M2[-1]    # Mass of carbon in "land/ocean" [GtC]

k12 = 0.0003    # Constant to describe land/ocean to atmosphere flux [1/yr] "turnover time or resonance time" [this is larger]
k21 = 0.1       # Constant to describe atmosphere to land/ocean flux [1/yr] "turnover time or resonance time"

ti = year[0]    # Initial time step [years]
tf = year[-1]   # Final time step [years]
dt = 1/365      # Time step interval

t = np.arange(ti,tf+dt,dt)               # Arrange the time steps

flux_mod = np.interp(t, year, cflux)     # Interpolate between years

Nt = flux_mod.size                       # Establish the length of time

print('t has '+str(Nt)+' time steps')    # Display the number of time steps we are using

M1 = np.zeros((Nt,))     # Create empty array to fill in for mass of carbon in atmosphere
M2 = np.zeros((Nt,))     # Create empty array to fill in for mass of carbon in the land/ocean
dM1 = np.zeros((Nt,))    # Create empty array to fill in for change in atmosphere at each time step
dM2 = np.zeros((Nt,))    # Create empty array to fill in for change in land/ocean at each time step

# This is the numerical solution

for i in np.arange(Nt):                        # Using a for loop, go through each equal time step in Nt and complete below
    if (i==0):                                 # If i = 0, then the mass in each "bin" equals the initial conditions

        M1[i] = M1i                            # Mass of carbon in atmosphere at time step 0 in array M1 is initial condition
        M2[i] = M2i                            # Mass of carbon in land/ocean at time step 0 in array M2 is initial condition
        
    else:                                      # If i /= 0, then complete the calculations below
        dM1dt = k21*flux_mod[i-1] - k12*flux_mod[i-1]      # Change in carbon in atmos wrt at i-1 equation
        dM2dt = k12*flux_mod[i-1] - k21*flux_mod[i-1]      # Change in carbon in land/ocean wrt at i-1 equation
        
        M1[i] = M1[i-1] + dM1dt*dt             # Insert value into M1 array of previous value plus the change calculated above
        M2[i] = M2[i-1] + dM2dt*dt             # Insert value into M2 array of previous value plus the change calculated above
        dM1[i] = dM1dt                         # Insert value for the change in atmosphere
        dM2[i] = dM2dt                         # Insert value for the change in and/ocean


print("Mass of Carbon in the Atmosphere [GtC]") # Print a label for value below
print(M1[-1])                                 # Display the last value in M1 array
print("Mass of Carbon in the Land/Ocean [GtC]") # Print a label for value below  
print(M2[-1])                                 # Display the last value in the M2 array
# Out:
# t has 93806 time steps
# Mass of Carbon in the Atmosphere [GtC]
# 1429.9338382172452
# Mass of Carbon in the Land/Ocean [GtC]
# -29.933838216990253

# %%
#### Problem B: Mass of C in the atmosphere versus time ####

plt.figure(figsize=(8.5,11))                              # Create a new plot
plt.rcParams.update({'font.size': 16})                    # Dictate the font size in the plot
plt.plot(t,M1)                                            # Give x and y values to the plot
plt.xlabel('Time [years]')                                # Create a label for the x axis
plt.ylabel('Carbon [GtC]')                                # Create a label for the y axis
plt.title('Mass of Carbon in the Atmosphere 1751-2008')   # Create a title for the entire plot
# Out:
# Text(0.5, 1.0, 'Mass of Carbon in the Atmosphere 1751-2008')

# %%
#### Problem B: Mass of C in the land versus time ####

plt.figure(figsize=(8.5,11))                              # Create a new plot
plt.rcParams.update({'font.size': 16})                    # Dictate the font size in the plot
plt.plot(t,M2)                                            # Give x and y values to the plot
plt.xlabel('Time [years]')                                # Create a label for the x axis
plt.ylabel('Carbon [GtC]')                                # Create a label for the y axis
plt.title('Mass of Carbon in the Land/Ocean 1751-2008')   # Create a title for the entire plot
# Out:
# Text(0.5, 1.0, 'Mass of Carbon in the Land/Ocean 1751-2008')

# %%
#### The change in mass of C in the atmosphere vs time ####

plt.figure(figsize=(8.5,11))                              # Create a new plot
plt.rcParams.update({'font.size': 16})                    # Dictate the font size in the plot
plt.plot(t,dM1)                                           # Give x and y values to the plot
plt.xlabel('Time [years]')                                # Create a label for the x axis
plt.ylabel('Carbon [GtC]')                                # Create a label for the y axis
plt.title('Change in Carbon in the Atmosphere 1751-2008') # Create a title for the entire plot
# Out:
# Text(0.5, 1.0, 'Change in Carbon in the Atmosphere 1751-2008')

# %%
#### The change in mass of C in the biosphere vs time ####

plt.figure(figsize=(8.5,11))                              # Create a new plot
plt.rcParams.update({'font.size': 16})                    # Dictate the font size in the plot
plt.plot(t,dM2)                                           # Give x and y values to the plot
plt.xlabel('Time [years]')                                # Create a label for the x axis
plt.ylabel('Carbon [GtC]')                                # Create a label for the y axis
plt.title('Change in Carbon in the Land/Ocean 1751-2008') # Create a title for the entire plot
# Out:
# Text(0.5, 1.0, 'Change in Carbon in the Land/Ocean 1751-2008')

# %%
#### Problem C ####

import numpy as np
import matplotlib.pyplot as plt

future_emissions_file = 'EmissionsMitigationScenarios.2008_2100.csv'

data = np.loadtxt(future_emissions_file, delimiter=',', skiprows=1)
year = data[:,0]
#print(len(year))
#print(year)
cflux_nz2030 = data[:,1]
#print(len(cflux_nz2030))
#print(cflux_nz2030)
cflux_nz2050 = data[:,2]
cflux_zeg = data[:,3]

# %%
#### Run the Model for Net Zero 2030 ####

M1i = M1[-1]    # Mass of carbon in atmosphere [Gigatons of Carbon, GtC]
M2i = M2[-1]    # Mass of carbon in "land/ocean" [GtC]

k12 = 0.0003    # Constant to describe land/ocean to atmosphere flux [1/yr] "turnover time or resonance time" [this is larger]
k21 = 0.1       # Constant to describe atmosphere to land/ocean flux [1/yr] "turnover time or resonance time"

ti = year[0]    # Initial time step [years]
tf = year[-1]   # Final time step [years]
dt = 1/365      # Time step interval

t = np.arange(ti,tf+dt,dt)                   # Arrange the time steps

flux_2030 = np.interp(t, year, cflux_nz2030) # Interpolate between years

Nt = flux_2030.size                          # Establish the length of time

print('t has '+str(Nt)+' time steps')        # Display the number of time steps we are using

M1_30 = np.zeros((Nt,))     # Create empty array to fill in for mass of carbon in atmosphere
M2_30 = np.zeros((Nt,))     # Create empty array to fill in for mass of carbon in the land/ocean
dM1_30 = np.zeros((Nt,))    # Create empty array to fill in for change in atmosphere at each time step
dM2_30 = np.zeros((Nt,))    # Create empty array to fill in for change in land/ocean at each time step

# This is the numerical solution

for i in np.arange(Nt):                        # Using a for loop, go through each equal time step in Nt and complete below
    if (i==0):                                 # If i = 0, then the mass in each "bin" equals the initial conditions

        M1_30[i] = M1i                            # Mass of carbon in atmosphere at time step 0 in array M1 is initial condition
        M2_30[i] = M2i                            # Mass of carbon in land/ocean at time step 0 in array M2 is initial condition
        
    else:                                      # If i /= 0, then complete the calculations below
        dM1dt = k21*flux_2030[i-1] - k12*flux_2030[i-1]      # Change in carbon in atmos wrt at i-1 equation
        dM2dt = k12*flux_2030[i-1] - k21*flux_2030[i-1]      # Change in carbon in land/ocean wrt at i-1 equation
        
        M1_30[i] = M1_30[i-1] + dM1dt*dt             # Insert value into M1 array of previous value plus the change calculated above
        M2_30[i] = M2_30[i-1] + dM2dt*dt             # Insert value into M2 array of previous value plus the change calculated above
        dM1_30[i] = dM1dt                         # Insert value for the change in atmosphere
        dM2_30[i] = dM2dt                         # Insert value for the change in and/ocean


print("Mass of Carbon in the Atmosphere [GtC]") # Print a label for value below
print(M1_30[-1])                                 # Display the last value in M1 array
print("Mass of Carbon in the Land/Ocean [GtC]") # Print a label for value below  
print(M2_30[-1])                                 # Display the last value in the M2 array
# Out:
# t has 33581 time steps
# Mass of Carbon in the Atmosphere [GtC]
# 1439.5227334650563
# Mass of Carbon in the Land/Ocean [GtC]
# -39.52273346480103

# %%
#### Run the Model for Net Zero 2050 ####

M1i = M1[-1]    # Mass of carbon in atmosphere [Gigatons of Carbon, GtC]
M2i = M2[-1]    # Mass of carbon in "land/ocean" [GtC]

k12 = 0.0003    # Constant to describe land/ocean to atmosphere flux [1/yr] "turnover time or resonance time" [this is larger]
k21 = 0.1       # Constant to describe atmosphere to land/ocean flux [1/yr] "turnover time or resonance time"

ti = year[0]    # Initial time step [years]
tf = year[-1]   # Final time step [years]
dt = 1/365      # Time step interval

t = np.arange(ti,tf+dt,dt)                   # Arrange the time steps

flux_2050 = np.interp(t, year, cflux_nz2050) # Interpolate between years

Nt = flux_2050.size                          # Establish the length of time

print('t has '+str(Nt)+' time steps')        # Display the number of time steps we are using

M1_50 = np.zeros((Nt,))     # Create empty array to fill in for mass of carbon in atmosphere
M2_50 = np.zeros((Nt,))     # Create empty array to fill in for mass of carbon in the land/ocean
dM1_50 = np.zeros((Nt,))    # Create empty array to fill in for change in atmosphere at each time step
dM2_50 = np.zeros((Nt,))    # Create empty array to fill in for change in land/ocean at each time step

# This is the numerical solution

for i in np.arange(Nt):                        # Using a for loop, go through each equal time step in Nt and complete below
    if (i==0):                                 # If i = 0, then the mass in each "bin" equals the initial conditions

        M1_50[i] = M1i                            # Mass of carbon in atmosphere at time step 0 in array M1 is initial condition
        M2_50[i] = M2i                            # Mass of carbon in land/ocean at time step 0 in array M2 is initial condition
        
    else:                                      # If i /= 0, then complete the calculations below
        dM1dt = k21*flux_2050[i-1] - k12*flux_2050[i-1]      # Change in carbon in atmos wrt at i-1 equation
        dM2dt = k12*flux_2050[i-1] - k21*flux_2050[i-1]      # Change in carbon in land/ocean wrt at i-1 equation
        
        M1_50[i] = M1_50[i-1] + dM1dt*dt             # Insert value into M1 array of previous value plus the change calculated above
        M2_50[i] = M2_50[i-1] + dM2dt*dt             # Insert value into M2 array of previous value plus the change calculated above
        dM1_50[i] = dM1dt                         # Insert value for the change in atmosphere
        dM2_50[i] = dM2dt                         # Insert value for the change in and/ocean

        
print("Mass of Carbon in the Atmosphere [GtC]") # Print a label for value below
print(M1_50[-1])                                 # Display the last value in M1 array
print("Mass of Carbon in the Land/Ocean [GtC]") # Print a label for value below  
print(M2_50[-1])                                 # Display the last value in the M2 array
# Out:
# t has 33581 time steps
# Mass of Carbon in the Atmosphere [GtC]
# 1448.2793844651837
# Mass of Carbon in the Land/Ocean [GtC]
# -48.279384464928455

# %%
#### Run the Model for Constant Emmissions ####

M1i = M1[-1]    # Mass of carbon in atmosphere [Gigatons of Carbon, GtC]
M2i = M2[-1]    # Mass of carbon in "land/ocean" [GtC]

k12 = 0.0003    # Constant to describe land/ocean to atmosphere flux [1/yr] "turnover time or resonance time" [this is larger]
k21 = 0.1       # Constant to describe atmosphere to land/ocean flux [1/yr] "turnover time or resonance time"

ti = year[0]    # Initial time step [years]
tf = year[-1]   # Final time step [years]
dt = 1/365      # Time step interval

t = np.arange(ti,tf+dt,dt)               # Arrange the time steps

flux_zeg = np.interp(t, year, cflux_zeg) # Interpolate between years

Nt = flux_zeg.size                       # Establish the length of time

print('t has '+str(Nt)+' time steps')    # Display the number of time steps we are using

M1_zeg = np.zeros((Nt,))     # Create empty array to fill in for mass of carbon in atmosphere
M2_zeg = np.zeros((Nt,))     # Create empty array to fill in for mass of carbon in the land/ocean
dM1_zeg = np.zeros((Nt,))    # Create empty array to fill in for change in atmosphere at each time step
dM2_zeg = np.zeros((Nt,))    # Create empty array to fill in for change in land/ocean at each time step

# This is the numerical solution

for i in np.arange(Nt):                        # Using a for loop, go through each equal time step in Nt and complete below
    if (i==0):                                 # If i = 0, then the mass in each "bin" equals the initial conditions

        M1_zeg[i] = M1i                            # Mass of carbon in atmosphere at time step 0 in array M1 is initial condition
        M2_zeg[i] = M2i                            # Mass of carbon in land/ocean at time step 0 in array M2 is initial condition
        
    else:                                      # If i /= 0, then complete the calculations below
        dM1dt = k21*flux_zeg[i-1] - k12*flux_zeg[i-1]      # Change in carbon in atmos wrt at i-1 equation
        dM2dt = k12*flux_zeg[i-1] - k21*flux_zeg[i-1]      # Change in carbon in land/ocean wrt at i-1 equation
        
        M1_zeg[i] = M1_zeg[i-1] + dM1dt*dt             # Insert value into M1 array of previous value plus the change calculated above
        M2_zeg[i] = M2_zeg[i-1] + dM2dt*dt             # Insert value into M2 array of previous value plus the change calculated above
        dM1_zeg[i] = dM1dt                         # Insert value for the change in atmosphere
        dM2_zeg[i] = dM2dt                         # Insert value for the change in and/ocean


print("Mass of Carbon in the Atmosphere [GtC]") # Print a label for value below
print(M1_zeg[-1])                                 # Display the last value in M1 array
print("Mass of Carbon in the Land/Ocean [GtC]") # Print a label for value below  
print(M2_zeg[-1])                                 # Display the last value in the M2 array
# Out:
# t has 33581 time steps
# Mass of Carbon in the Atmosphere [GtC]
# 1510.1831658158396
# Mass of Carbon in the Land/Ocean [GtC]
# -110.18316581701625

# %%
#### Mass of C in the atmosphere versus time (all three scenarios on one plot) ####

plt.figure(figsize=(8.5,11))
plt.rcParams.update({'font.size': 16})

plt.title('Mass of Carbon in the Atmosphere vs Time')
plt.plot(t,M1_30,'b-', label='Net Zero by 2030')
plt.plot(t,M1_50,'g-', label='Net Zero by 2050')
plt.plot(t,M1_zeg,'k-', label='Constant Emmissions')
plt.xlabel('Time [years]')
plt.ylabel('Carbon [GtC]')
plt.legend()

# %%
#### Mass of C in the land versus time (all three scenarios on one plot) ####

plt.figure(figsize=(8.5,11))
plt.rcParams.update({'font.size': 16})

plt.title('Mass of Carbon in the Land/Ocean vs Time')
plt.plot(t,M2_30,'b-', label='Net Zero by 2030')
plt.plot(t,M2_50,'g-', label='Net Zero by 2050')
plt.plot(t,M2_zeg,'k-', label='Constant Emmissions')
plt.xlabel('Time [years]')
plt.ylabel('Carbon [GtC]')
plt.legend()

# %%
#### The change in mass of C in the atmosphere vs time ####

plt.figure(figsize=(8.5,11))
plt.rcParams.update({'font.size': 16})

plt.title('Change in Carbon in the Atmosphere vs Time')
plt.plot(t,dM1_30,'b-', label='Net Zero by 2030')
plt.plot(t,dM1_50,'g-', label='Net Zero by 2050')
plt.plot(t,dM1_zeg,'k-', label='Constant Emmissions')
plt.xlabel('Time [years]')
plt.ylabel('Carbon [GtC]')
plt.legend()

# %%
#### The change in mass of C in the Land/Ocean vs time ####

plt.figure(figsize=(8.5,11))
plt.rcParams.update({'font.size': 16})

plt.title('Change in Carbon in the Land/Ocean vs Time')
plt.plot(t,dM2_30,'b-', label='Net Zero by 2030')
plt.plot(t,dM2_50,'g-', label='Net Zero by 2050')
plt.plot(t,dM2_zeg,'k-', label='Constant Emmissions')
plt.xlabel('Time [years]')
plt.ylabel('Carbon [GtC]')
plt.legend()
